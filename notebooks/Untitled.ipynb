# %%
import pandas as pd

# %%
catalog.list()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ['raw_pokemon_daataset', 'parameters']

# %%
df = catalog.load('raw_pokemon_daataset')
df
# Out:
# [11/16/23 16:35:57] INFO     Loading data from 'raw_pokemon_daataset' (CSVDataSet)...           data_catalog.py:502
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# ...

# %%
df.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# ...

# %%
df.isnull().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# ...

# %%
df_without_weights = df.drop(columns = ['type2','pokedex_number'])

# %%
df_without_weights.isnull().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# abilities             0
# against_bug           0
# against_dark          0
# against_dragon        0
# against_electric      0
# against_fairy         0
# against_fight         0
# against_fire          0
# against_flying        0
# against_ghost         0
# against_grass         0
# against_ground        0
# against_ice           0
# against_normal        0
# against_poison        0
# against_psychic       0
# against_rock          0
# against_steel         0
# against_water         0
# attack                0
# base_egg_steps        0
# base_happiness        0
# base_total            0
# capture_rate          0
# classfication         0
# defense               0
# experience_growth     0
# height_m             20
# hp                    0
# japanese_name         0
# name                  0
# percentage_male      98
# ...

# %%
df_without_weights_and_na = df_without_weights.dropna()

# %%
df_without_weights_and_na.isnull().sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# abilities            0
# against_bug          0
# against_dark         0
# against_dragon       0
# against_electric     0
# against_fairy        0
# against_fight        0
# against_fire         0
# against_flying       0
# against_ghost        0
# against_grass        0
# against_ground       0
# against_ice          0
# against_normal       0
# against_poison       0
# against_psychic      0
# against_rock         0
# against_steel        0
# against_water        0
# attack               0
# base_egg_steps       0
# base_happiness       0
# base_total           0
# capture_rate         0
# classfication        0
# defense              0
# experience_growth    0
# height_m             0
# hp                   0
# japanese_name        0
# name                 0
# percentage_male      0
# pokedex_number       0
# sp_attack            0
# ...

# %%
df_without_weights_and_na.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (684, 40)

# %%
def preprocess_pokemon(df: pd.DataFrame, selected_generation: [1]):
    ''' This function cleans the pokemon raw data, removing NAs and unused columns'''
    # removing unused columns
    df = df.drop(columns = ['type2','pokedex_number'])
    
    # removing Null values
    df = df.dropna() 
    
    # select generation
    df  = df[df.generation.isin([selected_generation])]
    return df

# %%
#testing function
df_cleaned = preprocess_pokemon(catalog.load('raw_pokemon_daataset'),[1,2,3])
df_cleaned
# Out:
# [11/16/23 16:57:24] INFO     Loading data from 'raw_pokemon_daataset' (CSVDataSet)...           data_catalog.py:502
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                        abilities  against_bug  against_dark  \
# 494                     ['Overgrow', 'Contrary']         2.00           1.0
# 495                     ['Overgrow', 'Contrary']         2.00           1.0
# 496                     ['Overgrow', 'Contrary']         2.00           1.0
# 497                       ['Blaze', 'Thick Fat']         0.50           1.0
# 498                       ['Blaze', 'Thick Fat']         0.25           0.5
# ..                                           ...          ...           ...
# 635                      ['Flame Body', 'Swarm']         0.50           1.0
# 636                      ['Flame Body', 'Swarm']         0.50           1.0
# ...

# %%
df.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (801, 41)

# %%
df['generation'].value_counts()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# generation
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     80
# 6     72
# Name: count, dtype: int64

# %%
de_selected = df[df.generation.isin([1])]
de_selected
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                          abilities  against_bug  against_dark  against_dragon  \
# 0      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# ..                             ...          ...           ...             ...
# 146  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 147  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 148  ['Inner Focus', 'Multiscale']          0.5           1.0             2.0
# ...

# %%
df_l  = df.loc[df.generation==1]
df_l
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                          abilities  against_bug  against_dark  against_dragon  \
# 0      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# ..                             ...          ...           ...             ...
# 146  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 147  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 148  ['Inner Focus', 'Multiscale']          0.5           1.0             2.0
# ...
